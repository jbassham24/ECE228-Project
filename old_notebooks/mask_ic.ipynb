# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
PATH_SOURCE = "/home/jbassham/jack/data/weddell/2020"
fnam = "con_nimbus7_latlon_sh_2020_2020.npz"
data = np.load(os.path.join(PATH_SOURCE, fnam), allow_pickle=True)
ic = data['ic']

# %%
plt.pcolormesh(ic[0,:,:])
plt.colorbar()
plt.show()

# %%
ic_raw = np.round(ic * 250)

# %%
plt.pcolormesh(ic_raw[0,:,:])
plt.colorbar()
plt.show()

# %%
# Mask 
# 251 pole hole
# 252 unused data
# 253 coastline
# 254 
ic_masked = np.where((ic_raw == 251) | (ic_raw == 252) | (ic_raw == 253) | (ic_raw == 254), np.nan, ic)

# %%
plt.pcolormesh(ic_masked[0,:,:])
plt.colorbar()
